# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.config import *
from src.load_data import load_prices, load_text_events
from src.sentiment import build_daily_sentiment
from src.features import prepare_features
from src.models import fit_arimax, fit_egarch, forecast_arimax, forecast_egarch
from src.evaluation import qlike, diebold_mariano
from src.backtest import sign_strategy
from src.utils_windows import rolling_splits
import yfinance as yf
import pandas as pd
import yfinance as yf
import pandas as pd

ticker = "SPY"
start = "2015-01-01"
end = "2025-01-01"

# Download data
data = yf.download(ticker, start=start, end=end)

# --- Flatten MultiIndex if it appears ---
if isinstance(data.columns, pd.MultiIndex):
    # Drop the second level (ticker names)
    data.columns = data.columns.get_level_values(0)

# --- Handle adjusted close / close fallback ---
price_col = "Adj Close" if "Adj Close" in data.columns else "Close"

# --- Save to CSV ---
data = data.reset_index()[["Date", price_col]]
data.columns = ["date", "close"]
data.to_csv("data/prices.csv", index=False)

print("✅ Saved to data/prices.csv with column:", price_col)
print(data.head())
# 1) Load Data
rets = load_prices()
texts = load_text_events()
daily_sent = build_daily_sentiment(texts)
df = prepare_features(rets, daily_sent)

dates = df.index
for i, (train_mask, test_mask) in enumerate(rolling_splits(dates)):
    print(f"Window {i+1}")
    print("Train:", df.index[train_mask][[0, -1]])
    print("Test :", df.index[test_mask][[0, -1]])
    print("-"*50)

# 2) Rolling window setup (reuse logic from old notebook or I’ll modularize next)
#    ...
# 3) Fit ARIMAX & EGARCH per window
#    ...
# 4) Collect forecasts, compute losses, DM tests
#    ...
# 5) Backtest
#    ...
# Out:
# /var/folders/70/wmwvzy0935xcgzk_jrn1_l400000gn/T/ipykernel_1720/726331664.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 36
#      34 data = data.reset_index()[["Date", price_col]]
#      35 data.columns = ["date", "close"]
# ---> 36 data.to_csv("data/prices.csv", index=False)
#      38 print("✅ Saved to data/prices.csv with column:", price_col)
#      39 print(data.head())
#
# File ~/miniconda3/envs/arimax-llm/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
# ...
